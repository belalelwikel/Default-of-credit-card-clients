# %% [markdown]
# # MCIT-AWS-Use Case 1

# %% [markdown]
# ### Use Cases – Default of Credit Card Clients

# %% [markdown]
# ## <a name ="0">Step</a>
# 1. <a href="#1">Import library</a>
# 2. <a href="#2">Read the dataset</a>
# 3. <a href="#3">Exploratory Data Analysis</a>
# 4. <a href="#4">split data and train  </a>

# %% [markdown]
# ## 1. <a name="1">Import library</a>
# (<a href="#0">Go to top</a>)

# %%
import numpy as np                                
import matplotlib.pyplot as plt   
import pandas as pd

# %% [markdown]
# ## 2. <a name="2">Read the dataset</a>
# (<a href="#0">Go to top</a>)
#
# Let's read the dataset into a dataframe, using Pandas.

# %%
df=pd.read_excel('default of credit card clients.xls',header=1)
print('The shape of the training dataset is:', df.shape)
# Out:
# The shape of the training dataset is: (30000, 25)

# %% [markdown]
# ## 2. <a name="3">Exploratory Data Analysis& Select features to build the model</a>
# (<a href="#0">Go to top</a>)
#
# We look at number of rows, columns and some simple statistics of the dataset.

# %%
df.head(20)
# Out:
#     ID  LIMIT_BAL     SEX        EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0    1      20000  female       university  married   24      2      2     -1
# 1    2     120000  female       university   single   26     -1      2      0
# 2    3      90000  female       university   single   34      0      0      0
# 3    4      50000  female       university  married   37      0      0      0
# 4    5      50000    male       university  married   57     -1      0     -1
# 5    6      50000    male  graduate school   single   37      0      0      0
# 6    7     500000    male  graduate school   single   29      0      0      0
# 7    8     100000  female       university   single   23      0     -1     -1
# 8    9     140000  female           others  married   28      0      0      2
# 9   10      20000    male      high school   single   35     -2     -2     -2
# 10  11     200000  female      high school   single   34      0      0      2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  object
#  3   EDUCATION                   29669 non-null  object
#  4   MARRIAGE                    29677 non-null  object
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
# Histograms for each numeric feature
display(df.describe())
display(df.describe(include=np.object))
#%matplotlib inline
hist = df.hist(bins=30, sharey=True, figsize=(10, 10))
# Out:
#                  ID       LIMIT_BAL           AGE         PAY_0         PAY_2  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667     35.518833     -0.016700     -0.133767
# std     8660.398374   129747.661567      9.528019      1.123802      1.197186
# min        1.000000    10000.000000     21.000000     -2.000000     -2.000000
# 25%     7500.750000    50000.000000     28.000000     -1.000000     -1.000000
# 50%    15000.500000   140000.000000     34.000000      0.000000      0.000000
# 75%    22500.250000   240000.000000     41.000000      0.000000      0.000000
# max    30000.000000  1000000.000000    267.000000      8.000000      8.000000
#
#               PAY_3         PAY_4         PAY_5         PAY_6      BILL_AMT1  \
# count  30000.000000  30000.000000  30000.000000  30000.000000   30000.000000
# mean      -0.166200     -0.220667     -0.266200     -0.291100   51223.330900
# ...

# %%
# Enter your code here
df.isnull().sum()
# Out:
# ID                              0
# LIMIT_BAL                       0
# SEX                             0
# EDUCATION                     331
# MARRIAGE                      323
# AGE                             0
# PAY_0                           0
# PAY_2                           0
# PAY_3                           0
# PAY_4                           0
# PAY_5                           0
# PAY_6                           0
# BILL_AMT1                       0
# BILL_AMT2                       0
# BILL_AMT3                       0
# BILL_AMT4                       0
# BILL_AMT5                       0
# BILL_AMT6                       0
# PAY_AMT1                        0
# PAY_AMT2                        0
# PAY_AMT3                        0
# PAY_AMT4                        0
# PAY_AMT5                        0
# PAY_AMT6                        0
# default payment next month      0
# dtype: int64

# %%
df.isna().any()
# Out:
# ID                            False
# LIMIT_BAL                     False
# SEX                           False
# EDUCATION                      True
# MARRIAGE                       True
# AGE                           False
# PAY_0                         False
# PAY_2                         False
# PAY_3                         False
# PAY_4                         False
# PAY_5                         False
# PAY_6                         False
# BILL_AMT1                     False
# BILL_AMT2                     False
# BILL_AMT3                     False
# BILL_AMT4                     False
# BILL_AMT5                     False
# BILL_AMT6                     False
# PAY_AMT1                      False
# PAY_AMT2                      False
# PAY_AMT3                      False
# PAY_AMT4                      False
# PAY_AMT5                      False
# PAY_AMT6                      False
# default payment next month    False
# dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df["EDUCATION"].fillna('university', inplace=True)
df["MARRIAGE"].fillna('single', inplace=True)

# %%
df.isna().any()
# Out:
# ID                            False
# LIMIT_BAL                     False
# SEX                           False
# EDUCATION                     False
# MARRIAGE                      False
# AGE                           False
# PAY_0                         False
# PAY_2                         False
# PAY_3                         False
# PAY_4                         False
# PAY_5                         False
# PAY_6                         False
# BILL_AMT1                     False
# BILL_AMT2                     False
# BILL_AMT3                     False
# BILL_AMT4                     False
# BILL_AMT5                     False
# BILL_AMT6                     False
# PAY_AMT1                      False
# PAY_AMT2                      False
# PAY_AMT3                      False
# PAY_AMT4                      False
# PAY_AMT5                      False
# PAY_AMT6                      False
# default payment next month    False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  object
#  3   EDUCATION                   30000 non-null  object
#  4   MARRIAGE                    30000 non-null  object
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.head(55)
# Out:
#     ID  LIMIT_BAL     SEX        EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0    1      20000  female       university  married   24      2      2     -1
# 1    2     120000  female       university   single   26     -1      2      0
# 2    3      90000  female       university   single   34      0      0      0
# 3    4      50000  female       university  married   37      0      0      0
# 4    5      50000    male       university  married   57     -1      0     -1
# 5    6      50000    male  graduate school   single   37      0      0      0
# 6    7     500000    male  graduate school   single   29      0      0      0
# 7    8     100000  female       university   single   23      0     -1     -1
# 8    9     140000  female           others  married   28      0      0      2
# 9   10      20000    male      high school   single   35     -2     -2     -2
# 10  11     200000  female      high school   single   34      0      0      2
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
clean_df=df.drop(['ID','default payment next month'],axis=1)
label=df['default payment next month']

# %%
clean_df.head()
# Out:
#    LIMIT_BAL     SEX   EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000  female  university  married   24      2      2     -1     -1
# 1     120000  female  university   single   26     -1      2      0      0
# 2      90000  female  university   single   34      0      0      0      0
# 3      50000  female  university  married   37      0      0      0      0
# 4      50000    male  university  married   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -2  ...        689          0          0          0         0       689
# 1      0  ...       2682       3272       3455       3261         0      1000
# 2      0  ...      13559      14331      14948      15549      1518      1500
# 3      0  ...      49291      28314      28959      29547      2000      2019
# 4      0  ...      35835      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
label.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: default payment next month, dtype: int64

# %%
clean_df.nunique()
# Out:
# LIMIT_BAL       81
# SEX              2
# EDUCATION        5
# MARRIAGE         3
# AGE             63
# PAY_0           11
# PAY_2           11
# PAY_3           11
# PAY_4           11
# PAY_5           10
# PAY_6           10
# BILL_AMT1    22723
# BILL_AMT2    22346
# BILL_AMT3    22026
# BILL_AMT4    21548
# BILL_AMT5    21010
# BILL_AMT6    20604
# PAY_AMT1      7943
# PAY_AMT2      7899
# PAY_AMT3      7518
# PAY_AMT4      6937
# PAY_AMT5      6897
# PAY_AMT6      6939
# dtype: int64

# %%
clean_df1=pd.get_dummies(clean_df, columns=['SEX','EDUCATION','MARRIAGE'])

# %%
import seaborn as sns

f, ax = plt.subplots(figsize=(32, 26))
corr = clean_df1.corr()
mp = sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax, annot = True)
mp.set_title(label='dataset correlation', fontsize=20)
# Out:
# Text(0.5, 1.0, 'dataset correlation')

# %%
clean_df1.head()
# Out:
#    LIMIT_BAL  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  \
# 0      20000   24      2      2     -1     -1     -2     -2       3913
# 1     120000   26     -1      2      0      0      0      2       2682
# 2      90000   34      0      0      0      0      0      0      29239
# 3      50000   37      0      0      0      0      0      0      46990
# 4      50000   57     -1      0     -1      0      0      0       8617
#
#    BILL_AMT2  ...  SEX_female  SEX_male  EDUCATION_0  \
# 0       3102  ...           1         0            0
# 1       1725  ...           1         0            0
# 2      14027  ...           1         0            0
# 3      48233  ...           1         0            0
# 4       5670  ...           0         1            0
#
#    EDUCATION_graduate school  EDUCATION_high school  EDUCATION_others  \
# 0                          0                      0                 0
# 1                          0                      0                 0
# ...

# %% [markdown]
# ## 4. <a name="4">split data & train </a>
# (<a href="#0">Go to top</a>)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(clean_df1 , label , test_size=0.2 ,shuffle=True, random_state=23)

# %%
from sklearn.preprocessing import StandardScaler
# Perform pre-processing to scale numeric features
scale = StandardScaler()
X_train = scale.fit_transform(X_train)

# Test features are scaled using the scaler computed for the training features
X_test = scale.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(n_estimators=10, random_state=1)

# %%
forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=1)

# %%
print(forest.score(X_train,y_train))
# Out:
# 0.9802916666666667

# %%
print(forest.score(X_test,y_test))
# Out:
# 0.8066666666666666

# %%
dt_predicted_labels=forest.predict(X_train)
dt_predicted_labels1=forest.predict(X_test)

# %%
from sklearn import metrics
print("Classification Report for", " :\n ",
      metrics.classification_report(y_test, dt_predicted_labels1))
# Out:
# Classification Report for  :
#                 precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88      4707
#            1       0.60      0.31      0.41      1293
#
#     accuracy                           0.81      6000
#    macro avg       0.72      0.63      0.65      6000
# weighted avg       0.78      0.81      0.78      6000

# %%
from sklearn import metrics
print("Classification Report for", " :\n ",
      metrics.classification_report(y_train, dt_predicted_labels))
# Out:
# Classification Report for  :
#                 precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     18657
#            1       0.99      0.92      0.95      5343
#
#     accuracy                           0.98     24000
#    macro avg       0.99      0.96      0.97     24000
# weighted avg       0.98      0.98      0.98     24000
